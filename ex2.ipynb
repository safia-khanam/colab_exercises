# %%
print("Hello Colab")
# Out:
# Hello Colab

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
print("Hello Colab")
# Out:
# Hello Colab

# %%
data = range(1,10)

# %%
print(data)
# Out:
# range(1, 10)

# %%
for val in data:
  print val
# Out:
#   File "<ipython-input-5-23142e0de4f2>", line 2
#     print val
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
for val in data:
  print(val)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
a=10

# %%
b=10

# %%
c=20
d=50

# %%
sum1=a+b

# %%
print(sum1)
# Out:
# 20

# %%
ss=30
yy=30
sum=ss + yy
print(sum)
# Out:
# 60

# %%
sum2=c+d

# %%
print(sum2)
